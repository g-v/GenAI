# %%
import cv2
import torch
from torchvision import transforms

# %%
# Load your PyTorch fire detection model
loaded_data = torch.load("C:\\user1\\python\\GenAI\\CODE\\model\\Fire_Detection.pt", weights_only=False)

# Assuming the actual model is stored under the key 'model' in the loaded dictionary
if isinstance(loaded_data, dict) and 'model' in loaded_data:
    model = loaded_data['model']
elif isinstance(loaded_data, torch.nn.Module):
    model = loaded_data
else:
    raise TypeError("The loaded file does not contain a PyTorch model in an expected format.")

model.eval()
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C2f(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
# Define preprocessing steps
preprocess = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
import os

# Specify the folder path containing your image frames
folder_path = 'C:\\user1\\python\\GenAI\\CODE\\images'

# List all files in the folder
image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Sort the image files to maintain order if necessary (e.g., frame_001.jpg, frame_002.jpg)
#image_files.sort()

frames = []
for image_file in image_files:
    img_path = os.path.join(folder_path, image_file)
    print(f"Processing image: {img_path}")
    # Read the image
    img = cv2.imread(img_path)
    if img is not None:
        frames.append(img)
        cv2.imshow("Fire Detection", img)
    else:
        print(f"Warning: Could not read image file: {img_path}")

print(f"Loaded {len(frames)} frames from {folder_path}")
# Out:
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne401_png.rf.59d8fdd5c328b3ff02fd4e088bfe43c4.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne448_png.rf.747407e468fadb88ad48d765c759345b.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne453_png.rf.63baf0682764422c6b4460de509ba49d.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne457_png.rf.18a9ab9976779fd6781e21284613807e.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne466_png.rf.6226dae1a175aa74990b8f1190f2784a.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne468_png.rf.1eecf50056001dd6c256e8a83f790806.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne522_png.rf.145fa94d033060927328862d15f5a459.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne563_png.rf.d27f8b4aa9907187ea92399e1ec534c9.jpg
# Processing image: C:\user1\python\GenAI\CODE\images\HouseOne608_png.rf.6bf2bcb43ec6dc1b39045d75e4c3db4e.jpg
# ...
